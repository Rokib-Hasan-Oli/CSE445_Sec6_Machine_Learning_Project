# %% [markdown]
# ## **Cell 12 — Save Comparison Images as ZIP**

# %%
import shutil
from pathlib import Path

PROJECT_ROOT = Path.home() / 'sr_project'
OUT_DIR      = PROJECT_ROOT / 'espcn_compare'   # ← add this line
CKPT         = PROJECT_ROOT / 'best_espcn_x4.pth'  # ← add this line
zip_path     = PROJECT_ROOT / 'espcn_compare'

shutil.make_archive(str(zip_path), 'zip', str(OUT_DIR))
print(f' Comparison images zipped → {zip_path}.zip')
print(f' Model checkpoint         → {CKPT}')
# Out:
#  Comparison images zipped → /home/rokib/sr_project/espcn_compare.zip
#  Model checkpoint         → /home/rokib/sr_project/best_espcn_x4.pth
